# %%
# read the file <- Memory 
df = spark.read.forma.....


df ( 10 columns)
schema 

Dynamic 

import time 
tt = time.time()

cols = df.columns()

DDL_string = f"CREATE TABLE CAMPAIGN_{tt} {cols} "


# create new table DDL 
# snowflake -----> compaigning 
# Data warehouse ( Dimesnsions & Facts )

# write to parquet 

create_save(df,DDL)

utility.py 

def create_save(df,ddl):

   conn = 
   conn.excute(ddl)

# %%
# catalyser Optimiser

# Plan
# 
# Analysis  | Logical Optimization | Physical Planning | Code Generation
