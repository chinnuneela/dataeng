# %%
# employee_src ( OLTP)

CREATE TABLE employee_src 
(
   emp_id INT,
   name STRING,
   department STRING,
   salary INT,
   effective_date DATE
);

# emplloyee_trg ( OLAP )

CREATE TABLE employee_trg
(
       emp_id INT,
       name STRING,
       department STRING,
       salary INT,
       effective_start_date DATE,
       effective_end_date DATE,
       flag BOOLEAN
);
