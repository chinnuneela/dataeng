# %% [markdown]
# **Classes and Objects**
# #### Basics

# %%
def execute(query):
   
   # logic to connect to db
   # establish connect
   # 
   # finally query execution 
   # 
   pass

def retrive_result(query):

    # logic to conne
    pass

# %%
# utility.py 

class person:

    def __init__(self,name="Mukesh",age=80):
        self.name = name.upper() 
        self.age = age 

    def greet(self):
        print(self.name)

    def write_subject(self,he):
        print(he)

# %%
person1 = person("Mukesh",80)

person1.greet()
person1.write_subject("hello")
# Out:
# MUKESH
# hello

# %%
person1

# %%
person2

# %% [markdown]
# **Inheritance**
