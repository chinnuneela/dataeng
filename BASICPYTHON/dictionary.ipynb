# %% [markdown]
# **dictinary in python**

# %% [markdown]
# lst = [1,2,3,45,6...........................65000.......................million ]
#
# Complexity : O(n) # worst case scenerio
#
# mydict = {"":"",.......................................................million }
#
# Complexity : O(1)
#
# List
# String
# Dict
# Tuple
# Set
#
# mydict = {}
#
# def process(st):
#     name = st['name']
#     return 0
#
# aws : policy
# DynamoDB :
# documentDB :

# %%
# Creating a dictinary 

lst = [1,2,3,4,5,5,5,5,1,2,3,4,6,6,6,6,66,6]

mydict = {}

#for i in range(len(lst)):      "key":"value"
for num in lst: 
    if num in mydict:
        mydict[num] += 1 
    else:
        mydict[num] = 1

print(mydict)
# Out:
# {1: 2, 2: 2, 3: 2, 4: 2, 5: 4, 6: 5, 66: 1}

# %%
# Given an array of integers arr, return true if the number of occurrences of each value 
# in the array is unique or false otherwise.
# arr = [1,2,2,1,1,3]


arr = [1,2,2,1,1,3]

def uniqueOccurrences(arr):

    mydict = {}
    for i in arr:
        if i in mydict:
            mydict[i] += 1
        else:
            mydict[i] = 1 
    return mydict 

aa = uniqueOccurrences(arr)         
print(aa)
# [3,2,1] True   {3:1,2:1,1:1}
# [3,3,2,1] False

x1 = aa.values()
x2 = set(x1)

print(x1)
print(x2)

print(len(x1) == len(x2))
# Out:
# {1: 3, 2: 2, 3: 1}
# dict_values([3, 2, 1])
# {1, 2, 3}
# True

# %%
word1 = 'abca'
word2 = 'bca'

dict1 = {}
dict2 = {}

for i in word1:
    if i in dict1:
        dict1[i] += 1
    else:
        dict1[i] = 1


for i in word2:
    if i in dict2:
        dict2[i] += 1
    else:
        dict2[i] = 1

print(f"values in dictionary1 : {dict1}")
print(f"values in dictionary2 : {dict2}")

print(dict1 == dict2)
# Out:
# values in dictionary1 : {'a': 2, 'b': 1, 'c': 1}
# values in dictionary2 : {'b': 1, 'c': 1, 'a': 1}
# False

# %% [markdown]
# Given an integer array nums, return an array answer such that answer[i] is equal to the product of all the elements of nums except nums[i].
#
# The product of any prefix or suffix of nums is guaranteed to fit in a 32-bit integer.
#
# You must write an algorithm that runs in O(n) time and without using the division operation.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,4]
# Output: [24,12,8,6]
# Example 2:
#
# Input: nums = [-1,1,0,-3,3]
# Output: [0,0,9,0,0]

# %%
nums = [1,2,3,4]
product = 1
answer = {}

for i in nums:
    product = product * i

for i in range(len(nums)):
    if nums[i] != 0:
        answer[i] = product/nums[i]

print(f"product is {product}")
print(f"answer is {answer}")
# Out:
# product is 24
# answer is {0: 24.0, 1: 12.0, 2: 8.0, 3: 6.0}

# %%
def productExceptSelf(nums):
        """
        :type nums: List[int]
        :rtype: List[int]
        """
        product = 1
        product_zero = 1    
        answer = [1] * len(nums)
        mydict = {}
        count = 0

        for i in range(len(nums)):
            if nums[i] == 0:
                count += 1
                if count > 1:
                    return [0] * len(nums)
        
                   
        for i in nums:
            product = product * i
            if i != 0:
                product_zero = product_zero * i


        for i in range(len(nums)):
            if nums[i] != 0:
                answer[i] = product/nums[i]
            else:
                answer[i] = product_zero

        
        return answer

nums1 = [1,2,3,4] # [24,12,8,6]
nums2 = [1,2,0,4] # [0,0,8,0]
nums3 = [1,2,0,0,5] #[0,0,0,0,0]

print(productExceptSelf(nums1))
print(productExceptSelf(nums2))
print(productExceptSelf(nums3))
# Out:
# [24.0, 12.0, 8.0, 6.0]
# [0.0, 0.0, 8, 0.0]
# [0, 0, 0, 0, 0]

# %%
def productExceptSelf1(nums):
    result = [1] * len(nums)

    left = 1

    for i in range(len(nums)):
        result[i] = left
        left = left * nums[i]
    


    right = 1

    for i in range(len(nums) - 1, -1, -1):
        result[i] = result[i] * right
        right = right * nums[i]

    return result

# %%
nums1 = [1,2,3,4] # [24,12,8,6]
nums2 = [1,2,0,4] # [0,0,8,0]
nums3 = [1,2,0,0,5] #[0,0,0,0,0]

print(productExceptSelf1(nums1))
print(productExceptSelf1(nums2))
print(productExceptSelf1(nums3))
# Out:
# [24, 12, 8, 6]
# [0, 0, 8, 0]
# [0, 0, 0, 0, 0]

# %% [markdown]
# replace vowels
# a='aalllliillllluullllllllii'

# %%
a='aalllliilllllallllllllii'
a=a.lower()
b = a
vowels = ['a','e','i','o','u']
a = [x for x in a]
print(f"list from a : {a}" )

left = 0
right = len(a) - 1



while(left < right):
    if ((a[left] in vowels) & (a[right] in vowels)):
        print(f"left: {left}  right : {right}  both are vowels {a[left]} and {a[right]}")
        a[left], a[right] = a [right], a[left]
        right = right - 1
        left = left + 1
    elif a[left] in vowels and a[right] not in vowels:
        right = right - 1
    else:
        left = left + 1

a=''.join(a)
print(b)
print(a)
# Out:
# list from a : ['a', 'a', 'l', 'l', 'l', 'l', 'i', 'i', 'l', 'l', 'l', 'l', 'l', 'a', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'i', 'i']
# left: 0  right : 23  both are vowels a and i
# left: 1  right : 22  both are vowels a and i
# left: 6  right : 13  both are vowels i and a
# aalllliilllllallllllllii
# iillllailllllillllllllaa
