# %%
import sys

# %%
#!pip install boto3 sample

# %%
#functions
# COBOL 
# decorators 

def somename():
    
    a = 4 

    return a

# %%
aa = somename()

print(aa)
# Out:
# 4

# %%
# classes
 
# class features
# 
# MYSQL -----> connection ---> query --> retrive ---> update  

class mysql_conn:

    def __init__():
        pass 

    def connect():
        pass 

    def executequery(query):
        pass 

obj1 = mysql_conn()
obj1.connect()
