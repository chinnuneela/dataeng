# %%
#!pip install snowflake-connector-python

# %%
import snowflake.connector

# %%
conn = snowflake.connector.connect(
                  user='CHINNUNEELA',
                  password='Yashwanth14181418',
                  account='TEMTDWR-EY78543',
                  database='TEST_DB',
                  schema='TEST_SCHEMA',
                  warehouse='COMPUTE_WH'
)

# %%
cursor = conn.cursor()
#conn.cursor().execute("USE WAREHOUSE COMPUTE_WH")
#conn.cursor().execute("SELECT count(*) FROM first_table")
cursor.execute("select count(*) from first_table")
cursor.execute("select * from first_table")

# %%
for row in cursor.fetchall():
    print(row)
# Out:
# (1,)
# (2,)
# (3,)
# (4,)
