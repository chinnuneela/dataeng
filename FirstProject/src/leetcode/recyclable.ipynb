# %%
import os

# Set the correct Java Home
os.environ['JAVA_HOME'] = "/opt/homebrew/opt/openjdk@17/libexec/openjdk.jdk/Contents/Home"

# Set the Spark Home
os.environ['SPARK_HOME'] = "/opt/homebrew/opt/apache-spark/libexec"

# %%
import pandas as pd

# %%
from pyspark.sql import SparkSession

# %%
data = [['0', 'Y', 'N'], ['1', 'Y', 'Y'], ['2', 'N', 'Y'], ['3', 'Y', 'Y'], ['4', 'N', 'N']]
products = pd.DataFrame(data, columns=['product_id', 'low_fats', 'recyclable']).astype({'product_id':'int64', 'low_fats':'category', 'recyclable':'category'})

# %%
products
# Out:
#    product_id low_fats recyclable
# 0           0        Y          N
# 1           1        Y          Y
# 2           2        N          Y
# 3           3        Y          Y
# 4           4        N          N

# %%
spark = SparkSession.builder.appName("recyclable").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/10/11 11:42:25 WARN Utils: Your hostname, mukeshs-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.29.221 instead (on interface en0)
# 25/10/11 11:42:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/11 11:42:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
print(spark.version)
# Out:
# 4.0.0

# %%
df_products = spark.createDataFrame(products)

print(df_products)
# Out:
# DataFrame[product_id: bigint, low_fats: string, recyclable: string]

# %%
df_products.show()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +----------+--------+----------+
# |product_id|low_fats|recyclable|
# +----------+--------+----------+
# |         0|       Y|         N|
# |         1|       Y|         Y|
# |         2|       N|         Y|
# |         3|       Y|         Y|
# |         4|       N|         N|
# +----------+--------+----------+

# %%
# Write a solution to find the ids of products that are both low fat and recyclable.

df_products.select("product_id").where((df_products["low_fats"] == 'Y') & (df_products["recyclable"] == "Y")).show()
# Out:
# +----------+
# |product_id|
# +----------+
# |         1|
# |         3|
# +----------+
